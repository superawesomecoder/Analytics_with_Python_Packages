# %%
import pandas as pd
import pandas_datareader.data as web
import numpy as np
import matplotlib.pyplot as plt
import random
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
file_name = 'loan.csv'

# %%
df= pd.read_csv('loan.csv', low_memory = False)
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
# 3  1076863    1277178    10000.0      10000.0          10000.0   36 months
# 4  1075358    1311748     3000.0       3000.0           3000.0   60 months
#
#    int_rate  installment grade sub_grade     ...      total_bal_il il_util  \
# 0     10.65       162.87     B        B2     ...               NaN     NaN
# 1     15.27        59.83     C        C4     ...               NaN     NaN
# 2     15.96        84.33     C        C5     ...               NaN     NaN
# 3     13.49       339.31     C        C1     ...               NaN     NaN
# 4     12.69        67.79     B        B5     ...               NaN     NaN
#
#   open_rv_12m  open_rv_24m max_bal_bc all_util total_rev_hi_lim inq_fi  \
# 0         NaN          NaN        NaN      NaN              NaN    NaN
# 1         NaN          NaN        NaN      NaN              NaN    NaN
# 2         NaN          NaN        NaN      NaN              NaN    NaN
# 3         NaN          NaN        NaN      NaN              NaN    NaN
# 4         NaN          NaN        NaN      NaN              NaN    NaN
#
#   total_cu_tl inq_last_12m
# 0         NaN          NaN
# 1         NaN          NaN
# 2         NaN          NaN
# 3         NaN          NaN
# 4         NaN          NaN
#
# [5 rows x 74 columns]

# %%
rows = df.index
row_count = len(rows)
random.shuffle(list(rows))

df.reindex(rows)

training_data = df[row_count // 10:]
testing_data = df[:row_count // 10]

# %%
testing_data.shape
# Out:
# (88737, 74)

# %%
training_data.shape
# Out:
# (798642, 74)

# %%
#I want to predict annual income to target
df1 = testing_data[['dti','funded_amnt','purpose']]

# %%
df1
# Out:
#          dti  funded_amnt             purpose
# 0      27.65       5000.0         credit_card
# 1       1.00       2500.0                 car
# 2       8.72       2400.0      small_business
# 3      20.00      10000.0               other
# 4      17.94       3000.0               other
# 5      11.20       5000.0             wedding
# 6      23.51       7000.0  debt_consolidation
# 7       5.35       3000.0                 car
# 8       5.55       5600.0      small_business
# 9      18.08       5375.0               other
# 10     16.12       6500.0  debt_consolidation
# 11     10.78      12000.0  debt_consolidation
# 12     10.08       9000.0  debt_consolidation
# 13     12.56       3000.0         credit_card
# 14      7.06      10000.0               other
# 15     20.31       1000.0  debt_consolidation
# 16     18.60      10000.0    home_improvement
# 17     10.52       3600.0      major_purchase
# 18     18.44       6000.0             medical
# 19      9.86       9200.0  debt_consolidation
# 20     26.53      20250.0  debt_consolidation
# 21     13.22      21000.0  debt_consolidation
# 22     11.18      10000.0         credit_card
# 23     16.01      10000.0  debt_consolidation
# 24      2.40       6000.0      major_purchase
# 25     29.44      15000.0         credit_card
# 26     15.22      15000.0  debt_consolidation
# 27     13.97       5000.0               other
# 28      5.63       4000.0  debt_consolidation
# 29     12.19       8500.0         credit_card
# ...      ...          ...                 ...
# 88707  19.17      10750.0         credit_card
# 88708   8.37      15000.0  debt_consolidation
# 88709  14.36      12800.0         credit_card
# 88710  27.04      24725.0  debt_consolidation
# 88711   9.26      10000.0         credit_card
# 88712  16.28      20400.0  debt_consolidation
# 88713   8.19       2800.0  debt_consolidation
# 88714  31.74      15000.0  debt_consolidation
# 88715  23.68      23850.0  debt_consolidation
# 88716  12.81      24000.0    home_improvement
# 88717  29.96      20000.0  debt_consolidation
# 88718  14.04       5000.0         credit_card
# 88719  18.77      20000.0         credit_card
# 88720  12.56       3750.0  debt_consolidation
# 88721  21.09      11800.0  debt_consolidation
# 88722  22.11      25000.0  debt_consolidation
# 88723  15.87       9450.0  debt_consolidation
# 88724   8.36      17625.0  debt_consolidation
# 88725   1.69      10625.0  debt_consolidation
# 88726  15.00       5000.0  debt_consolidation
# 88727  13.09      12000.0               other
# 88728  14.60       2800.0             medical
# 88729  31.31      18650.0  debt_consolidation
# 88730  34.67       8000.0  debt_consolidation
# 88731  17.78      13000.0  debt_consolidation
# 88732  17.93      10000.0  debt_consolidation
# 88733  26.40       6000.0         credit_card
# 88734  12.93      16000.0  debt_consolidation
# 88735  22.11       5125.0            vacation
# 88736   5.12       6500.0  debt_consolidation
#
# [88737 rows x 3 columns]

# %%
df1.shape
# Out:
# (88737, 3)

# %% [markdown]
# This section shows 10% of the data (sample pop.)

# %%
fig = plt.figure(1)
ax1 = fig.add_subplot(111)
ax1.set_xlabel('funded_amnt')
ax1.set_ylabel('dti')
ax1.set_title('DTI vs funded amount')
ax1.plot( 'funded_amnt','dti', data = df1);
plt.show()

# %% [markdown]
# This sections shows 50%

# %%
rows = training_data.index
row_count = len(rows)
random.shuffle(list(rows))

training_data.reindex(rows)

training_data2 = training_data[row_count // 10:]
testing_data2 = training_data[:row_count // 10]

# %%
testing_data2.shape
# Out:
# (79864, 74)

# %%
df2 = testing_data2[['dti','funded_amnt','purpose']]

# %%
df2
# Out:
#           dti  funded_amnt             purpose
# 88737   32.58       7750.0  debt_consolidation
# 88738   13.71      15000.0    home_improvement
# 88739   25.44      10000.0         credit_card
# 88740   22.52      18000.0  debt_consolidation
# 88741   11.06      22000.0               other
# 88742   24.21       7550.0  debt_consolidation
# 88743   19.45      17200.0         credit_card
# 88744   22.87      30000.0  debt_consolidation
# 88745   27.12       5500.0    home_improvement
# 88746   20.15      24000.0  debt_consolidation
# 88747    8.44       7000.0         credit_card
# 88748   23.00       8000.0         credit_card
# 88749   15.88      13000.0               house
# 88750    6.92      10200.0         credit_card
# 88751   16.62       7000.0  debt_consolidation
# 88752   17.08      20800.0  debt_consolidation
# 88753   10.13      14400.0         credit_card
# 88754    2.85      28000.0  debt_consolidation
# 88755   17.88      12000.0  debt_consolidation
# 88756   21.26      10000.0  debt_consolidation
# 88757   12.13      30000.0  debt_consolidation
# 88758   29.61      19075.0  debt_consolidation
# 88759    4.86       3200.0  debt_consolidation
# 88760   21.15      16000.0  debt_consolidation
# 88761   12.72      12000.0         credit_card
# 88762   21.53      12000.0  debt_consolidation
# 88763   23.57      18500.0         credit_card
# 88764   15.10      24000.0  debt_consolidation
# 88765    8.03      12000.0  debt_consolidation
# 88766   17.74      20000.0  debt_consolidation
# ...       ...          ...                 ...
# 168571   4.87      20000.0  debt_consolidation
# 168572  18.91      27000.0  debt_consolidation
# 168573  15.11       6500.0  debt_consolidation
# 168574  17.65      13000.0  debt_consolidation
# 168575   6.06      13000.0  debt_consolidation
# 168576  13.88      30225.0         credit_card
# 168577  19.54      18000.0  debt_consolidation
# 168578   3.19      18000.0  debt_consolidation
# 168579  31.85      26625.0  debt_consolidation
# 168580  20.06      12400.0         credit_card
# 168581  31.55      12000.0  debt_consolidation
# 168582  25.04      30000.0         credit_card
# 168583  24.07      19000.0  debt_consolidation
# 168584   4.03       4000.0  debt_consolidation
# 168585  26.06       5800.0  debt_consolidation
# 168586   5.40       8000.0         credit_card
# 168587  24.66      24000.0  debt_consolidation
# 168588  16.52      24375.0         credit_card
# 168589  20.36      18000.0    home_improvement
# 168590  18.98      28100.0         credit_card
# 168591  14.48      20000.0  debt_consolidation
# 168592  25.03      15000.0  debt_consolidation
# 168593  30.52      24575.0  debt_consolidation
# 168594  18.69      24175.0  debt_consolidation
# 168595   7.96      18375.0  debt_consolidation
# 168596  23.80      24000.0  debt_consolidation
# 168597  17.98      12000.0         credit_card
# 168598  18.50      35000.0  debt_consolidation
# 168599  23.94      30000.0  debt_consolidation
# 168600  18.75      14000.0         credit_card
#
# [79864 rows x 3 columns]

# %%
df2.shape
# Out:
# (79864, 3)

# %%
fig = plt.figure(1)
ax1 = fig.add_subplot(111)
ax1.set_xlabel('dti')
ax1.set_ylabel('funded_amnt')
ax1.set_title('DTI vs Funded Amount')
ax1.plot('dti', 'funded_amnt', data = df2);
plt.show()

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (11,6));
axes[0].plot('dti', 'funded_amnt', data = df1);
axes[0].set_title('Sample1: DTI vs Funded Amount');
axes[1].plot('dti', 'funded_amnt', data = df2);
axes[1].set_title('Sample2: DTI vs Funded Amount');

# %%
rows = training_data.index
row_count = len(rows)
random.shuffle(list(rows))

training_data.reindex(rows)

training_data3 = training_data[row_count // 10:]
testing_data3 = training_data[:row_count // 4]

# %%
testing_data3.shape
# Out:
# (199660, 74)

# %%
df3 = testing_data3[['dti','funded_amnt']]

# %%
df3.head(5)
# Out:
#          dti  funded_amnt
# 88737  32.58       7750.0
# 88738  13.71      15000.0
# 88739  25.44      10000.0
# 88740  22.52      18000.0
# 88741  11.06      22000.0

# %%
df3['Rolling_Mean'] = df3['funded_amnt'].rolling(window = 80).mean()
df3.head(10)
# Out:
# //anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#          dti  funded_amnt  Rolling_Mean
# 88737  32.58       7750.0           NaN
# 88738  13.71      15000.0           NaN
# 88739  25.44      10000.0           NaN
# 88740  22.52      18000.0           NaN
# 88741  11.06      22000.0           NaN
# 88742  24.21       7550.0           NaN
# 88743  19.45      17200.0           NaN
# 88744  22.87      30000.0           NaN
# 88745  27.12       5500.0           NaN
# 88746  20.15      24000.0           NaN

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (15,5));
axes[0].plot('funded_amnt', 'dti', data = df1);
axes[0].set_title('Sample1: DTI vs funded Amount');
axes[1].plot('funded_amnt', 'dti', data = df2);
axes[1].set_title('Sample1: DTI vs funded Amount');
axes[2].plot( 'Rolling_Mean','dti', data = df3);
axes[2].set_title('Smoothed Funded Amount(Rolling_Mean)');

# %%
df3_keypar = df3[(df3['funded_amnt'] >= 5000) & (df3['funded_amnt'] <= 35000)]

# %%
df3_keypar.head(5)
# Out:
#          dti  funded_amnt  Rolling_Mean
# 88737  32.58       7750.0           NaN
# 88738  13.71      15000.0           NaN
# 88739  25.44      10000.0           NaN
# 88740  22.52      18000.0           NaN
# 88741  11.06      22000.0           NaN

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression().fit(df3_keypar[['dti']], df3_keypar[['funded_amnt']])
m = model.coef_[0]
b = model.intercept_
#equation of the line
#print 'y = ', round(m[0],2), 'x + ', round(b[0],2) ~ get invalid syntax error so it didn't print go back and check on syntax 
# using the equation of the line to get y values
predicted_dti = model.predict(df3_keypar[['dti']])
predicted_dti[0:5]
# Out:
# array([[ 16039.6151259 ],
#        [ 15387.69541811],
#        [ 15792.94280404],
#        [ 15692.06280686],
#        [ 15296.14336588]])

# %%
predicted_dti = pd.DataFrame(data = predicted_dti, index = df3_keypar.index.values, columns = ['Predicted Funded Amount'])
predicted_dti.head(5)
# Out:
#        Predicted Funded Amount
# 88737             16039.615126
# 88738             15387.695418
# 88739             15792.942804
# 88740             15692.062807
# 88741             15296.143366

# %%
joined_df = df3_keypar.join(predicted_dti, how = 'inner')
joined_df.head()
# Out:
#          dti  funded_amnt  Rolling_Mean  Predicted Funded Amount
# 88737  32.58       7750.0           NaN             16039.615126
# 88738  13.71      15000.0           NaN             15387.695418
# 88739  25.44      10000.0           NaN             15792.942804
# 88740  22.52      18000.0           NaN             15692.062807
# 88741  11.06      22000.0           NaN             15296.143366

# %%
fig = plt.figure();
ax = fig.add_subplot(111);
ax.plot(joined_df['funded_amnt'], joined_df['Rolling_Mean'], color = (0,0,0), linewidth = 4, alpha = .9, label = 'Smoothed Funded Amount');
ax.plot(joined_df['funded_amnt'], joined_df['dti'], color = (1,0,0), label = 'Predicted Funded Amount');
ax.set_title('Smooth Funded Amount vs Linear Regression')
ax.set_xlabel('DTI')
ax.set_ylabel('Funded Amount')
ax.legend(loc='upper left');

# %%
import sklearn

r_squared = sklearn.metrics.r2_score(joined_df['funded_amnt'],joined_df['dti'],multioutput='uniform_average')
r_squared
# Out:
# -3.9615926412186857
